# %%
import extrudion as ex
import numpy as np
ex.analyzeDirectory('data')
# Out:
#             Max Stress [kPa]  Max Strain  Young Modulus [kPa]  \
# File
# 20230918_1           9.87698    0.255150            67.776105
# 20230918_2           6.73299    0.222671            40.492907
# 20230918_3          10.07540    0.255545            48.690636
# 20230918_4           9.45217    0.296509            41.197864
# 20230918_5          11.49150    0.375116            44.150070
#
#             Intercept [kPa]  Yield Stress [kPa]  Yield Strain
# File
# 20230918_1         0.083546             4.50117      0.084948
# 20230918_2         0.072563             5.38257      0.150930
# 20230918_3        -0.263602             8.61438      0.202255
# 20230918_4        -0.892863             8.81648      0.255924
# 20230918_5        -1.091025             9.31568      0.255924
