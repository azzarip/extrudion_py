# %%
import extrudion as ex
ex.start('.\data')
# Out:
# 20230918_1.TRA
# 20230918_2.TRA
# 20230918_3.TRA
# 20230918_4.TRA
# 20230918_5.TRA
# *********************************************
#                 EXTRUDION
# *********************************************
#
# by Paride Azzari (C) 2024
#
# info on: github.com/azzarip/extrudion
# *********************************************
# RESULTS:
#
# Analysis.csv contains the analyzed data
#
# The plots folder contains all the figures
# *********************************************

# %%
import pandas as pd
df = pd.read_table('data/20230918_1.TRA', header = [3], encoding = 'ANSI', sep = ',')
df['N'].max()
# Out:
# 0.987698

# %%
import extrudion.files as ex
file = ex.TRAFile('20230918_1.TRA', 'data')

file.analyze({'sample_area': 10, 'initial_length': 100})
# Out:
#    Max Stress [kPa]  Max Strain  Young Modulus [kPa]  Intercept [kPa]  \
# 0           98.7698    0.056504          2735.321762          1.32313
#
#    Yield Stress [kPa]  Yield Strain
# 0             98.3177      0.055371

# %%
98.7698*10/1000
# Out:
# 0.9876980000000001
