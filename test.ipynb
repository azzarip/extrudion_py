# %%
import extrudion as ex
ex.start('.\data')
# Out:
# 20230918_1.TRA
# ...
#    Max Stress [kPa]  Max Strain  Young Modulus [kPa]  Intercept [kPa]  \
# 0           49.3849    0.498288           128.532508         0.604581
#
#    Yield Stress [kPa]  Yield Strain            File
# 0             29.9055      0.248003  20230918_1.TRA
# 20230918_2.TRA
# ...
#    Max Stress [kPa]  Max Strain  Young Modulus [kPa]  Intercept [kPa]  \
# 0          33.66495    0.440989            78.572518         0.412871
#
#    Yield Stress [kPa]  Yield Strain            File
# 0            33.66495      0.440989  20230918_2.TRA
# 20230918_3.TRA
# ...
#    Max Stress [kPa]  Max Strain  Young Modulus [kPa]  Intercept [kPa]  \
# 0            50.377    0.498977            92.941142         0.318132
#
#    Yield Stress [kPa]  Yield Strain            File
# 0              5.2978      0.055469  20230918_3.TRA
# 20230918_4.TRA
# ...
#    Max Stress [kPa]  Max Strain  Young Modulus [kPa]  Intercept [kPa]  \
# 0          47.26085    0.569294            54.024968          0.18396
#
# ...

# %%
from extrudion.files import TRAFile
TRAFile('20230918_2.TRA', '.\data').analyze({'sample_area': 9, 'initial_length': 20})
# Out:
# ...
# 29 <- sD + r-> 29
#     strain      slope  intercept    error
# 0  0.03475  78.572518   0.412871  0.12415
#     strain      slope  intercept    error
# 0  0.03475  78.572518   0.412871  0.12415
#    Max Stress [kPa]  Max Strain  Young Modulus [kPa]  Intercept [kPa]  \
# 0          33.66495    0.440989            78.572518         0.412871
#
#    Yield Stress [kPa]  Yield Strain
# 0            33.66495      0.440989

# %%
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 TRAFile('20230918_2.TRA', '.\data').analyze({'sample_area': 9, 'initial_length': 20})
#
# File c:\Users\azzarip\Desktop\Projects\Corinna\extrudion\extrudion\files.py:97, in TRAFile.analyze(self, options)
#      95 data = StressStrain(self.data, sample_area=options['sample_area'], initial_length=options['initial_length'])
#      96 print(data)
# ---> 97 fit = Fit(data)
#      98 if "plot" not in options or options["plot"] is not False:
#      99     Plot(fit, data, self.filename)
#
# File c:\Users\azzarip\Desktop\Projects\Corinna\extrudion\extrudion\fit.py:13, in Fit.__init__(self, data, cut_off, fit_window)
#      10 if cut_off:
#      11     self.cutOffData()
# ---> 13 self.fit_results = self.getBestFit(fit_window)
#      14 self.results = self.getResults()
#
# ...
