# %%
import extrudion as ex
f = ex.analyzeDirectory('data', options={'sample_area': 10, 'initial_length': 20})
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import extrudion as ex
# ----> 2 f = ex.analyzeDirectory('data', options={'sample_area': 10, 'initial_length': 20})
#       3 f
#
# File c:\Users\azzarip\Desktop\Projects\Corinna\extrudion\extrudion\extrudion.py:11, in analyzeDirectory(folder_path, options)
#       6 '''
#       7 Give a folder path as a relative or absolute path, the script will analyze all the .TAR files found in the directory and return a DataFrame containing the results.
#       8 Leaving returns the Current Working Directory.
#       9 '''
#      10 from .files import TRAFolder
# ---> 11 return TRAFolder(folder_path).analyze(options)
#
# File c:\Users\azzarip\Desktop\Projects\Corinna\extrudion\extrudion\files.py:21, in TRAFolder.analyze(self, options)
#      18 import pandas as pd
#      20 for file in self.file_list:
# ...
